# %%
import importlib
import Data_process_and_visulization_1 as dpv
# Out:
# input the address of GDP data:C:/Users/56284/OneDrive/study/quarter 4/data analysis ECE143/PROJECT/GDP.xlsx
# input the addess of Movies data:C:/Users/56284/OneDrive/study/quarter 4/data analysis ECE143/PROJECT/movies.csv

# %% [markdown]
# First input the address of the GDP data, then input the address of Movies data, no need to add quotation mark.
# For me, it is C:/Users/56284/OneDrive/study/quarter 4/data analysis ECE143/PROJECT/GDP.xlsx and
# C:/Users/56284/OneDrive/study/quarter 4/data analysis ECE143/PROJECT/movies.csv

# %% [markdown]
# if the py.file doesn't refesh, use the code below
# importlib.reload(dpv)

# %%
dpv.MGY()

# %% [markdown]
# - This plot shows rise in the Movie Industry Gross.
# - A peak in the movie industry in 1930s and 1990s. It is a good time for movie industry because US economy in these decades was not good and people were more willing to pay for movies.

# %%
dpv.NMG()

# %% [markdown]
# - This plot shows the number of movies in each genre in the history of movie industry.
# - Comedy, Drama and Action are more than the others.

# %%
dpv.ARHY()

# %% [markdown]
# - Green curve => average runtime for all of the movies, Orange curve => average runtime for highly rated movies.
# - General increase in average runtime during the history of movie making and again you can seen that the average runtime of all movies is around the average runtime of highly rated movies.

# %%
dpv.AGBRG()

# %% [markdown]
# - This plot shows average of Gross/Budget for all genres.
# - Most Profitable Genres => Musical, Horror, Fantasy.
# - Least Profitable Genres => Music Videos, Thriller, Sci-Fi.
# - Strict Line is one.

# %%
dpv.NGBRGC()

# %% [markdown]
# - This plot shows the number movies that are profitable and number of movies that are loss making in different genres.
# - Although in the last figure mean of Gross/Budget ratio was high for Comedy, it may be also loss making => High Risk in Comedy Genre, More Profit in Popular Comedy Movies compared to popular movies in other genres.

# %%
dpv.TLG1950()

# %% [markdown]
# - In this plot, we investigated the effect of length of title versus the mean of gross/budget ratio.
# - Not too much correlation between gb ratio and length of title BUT Decrease in gb ratio when length of title is too long.

# %%
dpv.GB()
# Out:
# C:\Users\56284\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# - This plot shows the Correlation between Gross and Budget.
# - Profit Definition: Gross => High Correlation Between Budget and Profit because correlation coefficient is close to one.

# %%
dpv.GBRB()
# Out:
# C:\Users\56284\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# - This plot shows the correlation between Gross and gb ratio.
# - Profit Definition: Gross/Budget => No Correlation Between Budget and Profit because correlation coefficient is near zero.

# %%
dpv.WNB()
# Out:
# C:\Users\56284\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# - This plot shows the correlation between Number of wins and nominations and Budget.
# - Very low Correlation Between Wins/Nomins and Budget.

# %%
dpv.BR()
# Out:
# C:\Users\56284\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# - This plot shows the correlation between tomato rating and Budget.
# - Not too much correlation Between Tomato Rating  and Budget.

# %%
dpv.NANTR()
# Out:
# C:\Users\56284\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# - Wins/Nomins and imdbRating correlation < Wins/Nomins and tomatoRating correlation.
# - This is because tomatoRating is for critics and imdbRating is for Ordinary viewers.

# %%
dpv.NANIT()
# Out:
# C:\Users\56284\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# - Wins/Nomins and imdbRating correlation < Wins/Nomins and tomatoRating correlation.
# - This is because tomatoRating is for critics and imdbRating is for Ordinary viewers.

# %%
dpv.GDG()
# Out:
# C:\Users\56284\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# - This plot shows the high correlation between domestic gross and gross all over the world.
# - Most of the movies are made in US. So we can conclude that if Americans like a movie and pay for it then most of the people will like it and pay for it with high probability.

# %%
dpv.RGBR1950()

# %% [markdown]
# - Optimum Length of the Movie for More Profit => (140,170) minutes.

# %%
dpv.BRM()

# %% [markdown]
# - Release May, June, July, December => More probable to have a very high gross.
# - If a streaming company consider a movie as a profitable movies it is better to release it in May, June, July and December.
# - Do not release in September, October and April.

# %%
dpv.TRG()
# Out:
# C:\Users\56284\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# - Gross and imdbRating correlation > Gross and tomatoRating correlation => tomatoRating is for critics and imdbRating is for Audience.

# %%
dpv.IRG()
# Out:
# C:\Users\56284\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# - Gross and imdbRating correlation > Gross and tomatoRating correlation => tomatoRating is for critics and imdbRating is for Audience.
